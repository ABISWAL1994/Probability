# %% [markdown]
# #PROBABILITY

# %% [markdown]
#  1. (A) Total number of favorable outcome is 3
#         total number of outcomes is 6
#         so probability of getting even number is 3/6 = 1/2 = 50%
#
#     (B) Total number of favorable outcome is 2
#         Total number of outcomes is 6
#         so probability of getting number greater than 4 is
#         2/6 = 1/3 = 33.33%
#
#  2. out of 50 students
#     20 like mathematica
#     15 likes science
#     5 likes both
#     so student likes math or science is
#     (20)+(15)-(5) = 30
#
#      so total favorable outcomes is 30
#      total outcomes 50
#      so probability of random likes is 30/50 = 3/5 = 0.6 or 60%
#
#   3. A bag has 3red and 2 blue ball so total no of ball count is 5
#      if one ball is drawn and is red so 4 ball left in that bucket (without replacing)
#      now in that bucket red ball left 2 and blue ball left 2
#      total favorable outcomes is 2
#      total outcomes is 4
#      probability of getting nexball red is 2/4 = 1/2 = 50%
#
#   4. I will use Stratified method because as per the question we have to
#      equal represent of both gender which is not possible in random sampling.
#
#   5. Because of faulty sampling frame
#
#   6. Standard Error of mean is 5000/sqrt{100} = 50
#
#   7. cricket likes 40 students
#      football like 30 students
#      and 10 likes boths
#      so student likes at least one sports is
#      (C U F) = (40)+(30)-(10) = 60
#      Probability is 60/100 = 0.6 or 60%
#
#   8. in the deck of 52 cards there is 4 Aces
#      so probability of 1st one is Ace = 4/52 = 1/13
#      as two card drawn at time so 51 cards left in that deck and 3 ace is there
#      so probabilty of 2nd ace is = 3/51 = 1/17
#
#      total probability is 1/13 * 1/17 = 1/221
#
#   9. Not answered
#
#  10. Discrete is Countable which is whole number where as Continuous variable is any value within a interval
#     Discrete Example - the number of student present in the classroom
#      Continuous variable example - what is the Room temperature
